# %%
import requests
import pandas as pd

# %%
def get_most_popular_games(num_games):
    if num_games > 100:
        print("can only have 100 games")
        num_games = 100
    
    steam_url = "https://steamspy.com/api.php?request=top100in2weeks"
    response = requests.get(steam_url)
    data = response.json()

    response_df = pd.DataFrame.from_dict(data, orient="index").reset_index(drop=True)
    response_df.to_csv('../../data/top_100_games.csv', index=False)
    return response_df

# %%
df = get_most_popular_games(100)

# %%
df.head()
# Out:
#      appid                              name         developer  \
# 0      730  Counter-Strike: Global Offensive             Valve
# 1  1172470                      Apex Legends           Respawn
# 2   578080               PUBG: BATTLEGROUNDS  PUBG Corporation
# 3  1623730                          Palworld        Pocketpair
# 4      440                   Team Fortress 2             Valve
#
#          publisher score_rank  positive  negative  userscore  \
# 0            Valve              7642084   1173003          0
# 1  Electronic Arts               668053    326926          0
# 2    KRAFTON, Inc.              1520457   1037487          0
# 3       Pocketpair               358266     22443          0
# 4            Valve              1044264    117208          0
#
#                        owners  average_forever  average_2weeks  \
# 0  100,000,000 .. 200,000,000            31732             862
# 1  100,000,000 .. 200,000,000             9929             716
# ...
